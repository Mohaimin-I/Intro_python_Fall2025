# %% [markdown]
# # Comprehensive Basic Python Course

# %% [markdown]
# # Variables and Operators

# %% [markdown]
# Variables are names given to data that we need to store and manipulate in our programs.
#
# variable_Name = initial value

# %%
userAge = 0
print('Age = ', userAge)
userAge, userName = 30, 'Peter'
print('Age = ', userAge,';', 'Name = ', userName)

# %% [markdown]
# Naming a Variable

# %% [markdown]
# A variable name in Python can only contain letters (a - z, A - B), numbers or underscores (_). However, the first character cannot be a number.

# %%
userName = 'John' 
print(userName)
user_name = 'Manto'
print(user_name)
userName2 = 'Jahir'
print(userName2)

# %%
#2username = 'Gary'

# %% [markdown]
# In addition, there are some reserved words that you should not use as a variable name because they already have preassigned meanings in Python. These reserved words include words like print, input, if, while etc.

# %%
#print = 3
input = 2
print(input)
del input

# %% [markdown]
# Finally, variable names are case sensitive. username is not the same as userName.

# %%
username = 'Caleb'
userName = 'Sarah'
print(username)
print(userName)

# %% [markdown]
# The Assignment Sign

# %% [markdown]
# Note that the = sign in the statement userAge = 0 has a different meaning from the = sign we learned in Math. In programming, the = sign is known as an assignment sign. A good way to understand the statement userAge = 0 is to think of it as userAge <- 0. The statements x = y and y = x have very different meanings in programming.

# %%
x = 5
y = 10
#x = y
#y = x
print ("x = ", x)
print ("y = ", y)

# %% [markdown]
# Basic Operators

# %% [markdown]
# Besides assigning a variable an initial value, we can also perform the usual mathematical operations on variables. Basic operators in Python include +, -, *, /, //, % and ** which represent addition, subtraction, multiplication, division, floor division, modulus and exponent respectively.

# %%
x = 5
y = 2
print('Addition = ', x+y)
print('Subtraction = ', x-y)  
print('Multiplication = ', x * y)
print('Division = ', x / y)
print('Floor Division = ', x // y) # (rounds down the answer to the nearest whole number)
print('Modulus = ', x % y) #(gives the remainder when x is divided by y)
print('Exponent = ', x ** y)

# %% [markdown]
# More Assignment Operators

# %% [markdown]
# Besides the = sign, there are a few more assignment operators in Python (and most programming languages). These include operators like +=, -= and *=.

# %%
x = 10 
x = x + 2
print('x + 2 :', x)
x = 10
x += 2
print('x += 2 :', x)
x -= 2
print('x -= 2 :',x)
x *= 2
print('x *= 2 :',x)

# %% [markdown]
# # Data Types in Python

# %% [markdown]
# Basic data types: integer, float and string.
# Advanced data types: list, tuple and dictionary

# %% [markdown]
# Integer

# %% [markdown]
# Integers are numbers with no decimal parts, such as -5, -4, -3, 0, 5,
# 7 etc.
# To declare an integer in Python, simply write variableName =
# initial value

# %%
userAge = 20
mobileNumber = 1234567678
print(userAge, mobileNumber)

# %% [markdown]
# Float

# %% [markdown]
# Float refers to numbers that have decimal parts, such as 1.234,
# -0.023, 12.01.
# To declare a float in Python, we write variableName = initial
# value

# %%
userHeight = 1.82
userWeight = 67.2
print(userHeight, userWeight)

# %% [markdown]
# String

# %% [markdown]
# String refers to text.
# To declare a string, you can either use variableName =
# ‘initial value’ (single quotes) or variableName =
# “initial value” (double quotes)

# %%
userName = 'Peter'
userSpouseName = 'Janet'
userAge = '30'
print(userName, userSpouseName,userAge)
#userSpouseAge = 25
#totalAge = userSpouseAge + userAge
#print(totalAge)

# %% [markdown]
# We can combine multiple substrings by using the concatenate sign
# (+).

# %%
concatenation = 'Peter' + 'Lee'
print(concatenation)

# %% [markdown]
# Built-In String Functions

# %% [markdown]
# Python includes a number of built-in functions to manipulate strings.
# A function is simply a block of reusable code that performs a certain
# task like print(). An example of a function available in Python is the upper() method
# for strings.

# %%
s = " Hello world "
print(s)
u = s.upper()      # " HELLO WORLD "  → all uppercase
print(u)
l = s.lower()      # " hello world "  → all lowercase
print(l)
t = s.title()      # " Hello World "  → title case
print(t)
c = s.capitalize() # " hello world " → only first letter uppercase
print(c)
s = s.swapcase()   # " HELLO WORLD " → swaps case
print(s)

# %% [markdown]
# Type Casting in Python

# %% [markdown]
# Sometimes in our program, it is necessary for us to convert from one
# data type to another, such as from an integer to a string. This is
# known as type casting.
# There are three built-in functions in Python that allow us to do type
# casting. These are the int(), float(), and str() functions.

# %%
integer = int(5.321)
float_number = float(4)
string_text = str(integer)
#add = integer + string_text
float_from_string = float('3')
addition = float_number + float_from_string
print(integer, float_number, string_text, addition)

# %% [markdown]
# However, you cannot do

# %%
#int('Hello World')
#int('4.123')

# %% [markdown]
# List

# %% [markdown]
# List refers to a collection of data which are normally related. Instead
# of storing these data as separate variables, we can store them as a
# list. For instance, suppose our program needs to store the age of 5
# users. Instead of storing them as user1Age, user2Age,
# user3Age, user4Age and user5Age, it makes more sense to
# store them as a list.
# To declare a list, you write listName = [initial values].
# Note that we use square brackets [ ] when declaring a list. Multiple
# values are separated by a comma

# %%
userAge = [21, 22, 23, 24, 25]
print(userAge)

# %% [markdown]
# We can also declare a list without assigning any initial values to it.
# We simply write listName = []. What we have now is an empty
# list with no items in it. We have to use the append() method
# mentioned below to add items to the list.

# %%
Listname = []
print(Listname)
Listname.append(12)
print(Listname)

# %% [markdown]
# Individual values in the list are accessible by their indexes, and
# indexes always start from ZERO, not 1. Hence the
# first value has an index of 0, the next has an index of 1 and so forth.

# %%
print(userAge[0], userAge[1])

# %% [markdown]
# Alternatively, you can access the values of a list from the back. The
# last item in the list has an index of -1, the second last has an index of
# -2 and so forth.

# %%
print(userAge[-1], userAge[-2])

# %% [markdown]
# You can assign a list, or part of it, to a variable

# %%
userAge2 = userAge
print(userAge2)
userAge3 = userAge[2:4]
print(userAge3)

# %% [markdown]
# The notation 2:4 is known as a slice. Whenever we use the slice
# notation in Python, the item at the start index is always included, but
# the item at the end is always excluded. Hence the notation 2:4 refers
# to items from index 2 to index 4-1 (i.e. index 3), which is why
# userAge3 = [23, 24] and not [23, 24, 25].

# %% [markdown]
# The slice notation includes a third number known as the stepper.

# %%
userAge4 = userAge[1:5:2]
print(userAge4)

# %% [markdown]
# In addition, slice notations have useful defaults. The default for the
# first number is zero, and the default for the second number is size of
# the list being sliced. For instance, userAge[ :4] gives you values
# from index 0 to index 4-1 while userAge[1: ] gives you values
# from index 1 to index 5-1

# %%
print(userAge[:], userAge[:4], userAge[1:])

# %% [markdown]
# To modify items in a list, we write listName[index of item to
# be modified] = new value.

# %%
userAge[1] = 5
print(userAge)

# %% [markdown]
# To add items, you use the append() function.

# %%
userAge.append(99)
print(userAge)

# %% [markdown]
# To remove items, you write del listName[index of item to
# be deleted].

# %%
del userAge[-1]
print(userAge)

# %% [markdown]
# Try the following by yourself.
# #1. Declaring the list, list elements can be of
# different data types.
# myList = [1, 2, 3, 4, 5, “Hello”]

# %% [markdown]
# 2. print the entire list. #3. print the third item (recall: Index starts from
# zero). #4. print the last item.

# %% [markdown]
# 5. assign myList (from index 1 to 4) to myList2 and
# print myList2

# %% [markdown]
# 6. modify the second item in myList and print the
# updated list. #7. append a new item to myList and print the updated
# list. #8. remove the sixth item from myList and print the
# updated list

# %% [markdown]
# Tuple

# %% [markdown]
# Tuples are just like lists, but you cannot modify their values. The
# initial values are the values that will stay for the rest of the program.
# An example where tuples are useful is when your program needs to
# store the names of the months of the year.

# %% [markdown]
# To declare a tuple, you write tupleName = (initial values).
# Notice that we use round brackets ( ) when declaring a tuple.
# Multiple values are separated by a comma.

# %%
monthsOfYear = ('Jan', 'Feb', 'Mar', 'Apr', 'May',
'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec')
print(monthsOfYear)

# %% [markdown]
# You access the individual values of a tuple using their indexes, just
# like with a list.

# %%
print(monthsOfYear[0], monthsOfYear[-1])

# %% [markdown]
# Dictionary

# %% [markdown]
# Dictionary is a collection of related data PAIRS. For instance, if we
# want to store the username and age of 5 users, we can store them in
# a dictionary.

# %% [markdown]
# To declare a dictionary, you write dictionaryName =
# {dictionary key : data}, with the requirement that dictionary
# keys must be unique (within one dictionary). That is, you cannot
# declare a dictionary like this
# myDictionary = {“Pete r”:38, “John”:51, “Peter”:13}.

# %%
userNameAndAge = {'Peter':38, 'John':51,
'Alex':13, 'Alvin':'Not Available'}
print(userNameAndAge)

# %% [markdown]
# You can also declare a dictionary using the dict( ) method. When you use this method to declare a dictionary, you use round
# brackets ( ) instead of curly brackets { } and you do not put quotation
# marks for the dictionary keys.

# %%
userNameAndAge = dict(Peter = 38, John = 51, Alex
= 13, Alvin = 'Not Available')
print(userNameAndAge)

# %% [markdown]
# To access individual items in the dictionary, we use the dictionary
# key, which is the first value in the {dictionary key : data}
# pair.

# %%
print(userNameAndAge['John'])

# %% [markdown]
# To modify items in a dictionary, we write
# dictionaryName[dictionary key of item to be
# modified] = new data.

# %%
userNameAndAge['John'] = 21
print(userNameAndAge)

# %% [markdown]
# We can also declare a dictionary without assigning any initial values
# to it. To add items to a dictionary, we write
# dictionaryName[dictionary key] = data.

# %%
dictionaryName = {}
print(dictionaryName)
userNameAndAge['Joe'] = 40
print(userNameAndAge)

# %% [markdown]
# To remove items from a dictionary, we write del
# dictionaryName[dictionary key].

# %%
del userNameAndAge['Alex']
print(userNameAndAge)

# %% [markdown]
# Run the following program to see all these in action.

# %% [markdown]
# 1. declaring the dictionary, dictionary keys and
# data can be of different data types
# myDict = {'One':1.35, 2.5:'Two Point Five', 3:'+',
# 7.9:2}. #2. print the entire dictionary. Note that items in a dictionary are not stored in
# the same order as the way you declare them.

# %% [markdown]
# 3. print the item with key = 'One'. #4. print the item with key = 7.9. #5. modify the item with key = 2.5 and print the
# updated dictionary

# %% [markdown]
# 6. add a new item and print the updated dictionary
# myDict['New item'] = "I'm new". #7. remove the item with key = 'One' and print the
# updated dictionary
